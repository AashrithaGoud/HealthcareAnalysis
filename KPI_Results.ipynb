# %%
DBFS_FILE_PATH = "dbfs:/mnt/HealthcareKPI"

# %%
display(spark.read.format("parquet").load(f"{DBFS_FILE_PATH}/disease_deceased_count.parquet"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.format("parquet").load(f"{DBFS_FILE_PATH}/success_rate_by_age.parquet"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.format("parquet").load(f"{DBFS_FILE_PATH}/treatment_cost_by_disease_name.parquet"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.format("parquet").load(f"{DBFS_FILE_PATH}/treatment_duration_treatment_type.parquet"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>treatment_type</th><th>sum(treatment_duration)</th></tr></thead><tbody><tr><td>therapeutic</td><td>786090</td></tr><tr><td>preventive</td><td>790031</td></tr><tr><td>surgical</td><td>787187</td></tr><tr><td>pharmacological</td><td>785347</td></tr></tbody></table></div>

# %%
display(spark.read.format("parquet").load(f"{DBFS_FILE_PATH}/treatment_type_success_rate.parquet"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>treatment_type</th><th>treatment_outcome_status</th><th>count_of_patients</th><th>total_patients</th><th>success_rate</th></tr></thead><tbody><tr><td>preventive</td><td>successful</td><td>21860</td><td>175678</td><td>12.44</td></tr><tr><td>surgical</td><td>successful</td><td>21807</td><td>174874</td><td>12.47</td></tr><tr><td>therapeutic</td><td>successful</td><td>21987</td><td>174866</td><td>12.57</td></tr><tr><td>pharmacological</td><td>successful</td><td>21726</td><td>174582</td><td>12.44</td></tr></tbody></table></div>
